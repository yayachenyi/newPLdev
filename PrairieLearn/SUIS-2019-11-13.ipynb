# %%
import turtle as t
t.speed(5)
t.screensize(800,600,"purple")
t.penup()
# t.goto(100,200)
t.forward(20)
t.pendown()
t.dot(30)
t.forward(100)
t.dot()
t.circle(50)
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-11-f2905179c139> in <module>()
#      11 t.circle(50)
#      12 t.done()
# ---> 13 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
"""
绘制小猪佩奇
"""



from turtle import *


def nose(x,y):
    """画鼻子"""
    penup()
    # 将海龟移动到指定的坐标
    goto(x,y)
    pendown()
    # 设置海龟的方向（0-东、90-北、180-西、270-南）
    setheading(-30)
    begin_fill()
    a = 0.4
    for i in range(120):
        if 0 <= i < 30 or 60 <= i <90:
            a = a + 0.08
            # 向左转3度
            left(3)
            # 向前走
            forward(a)
        else:
            a = a - 0.08
            left(3)
            forward(a)
    end_fill()
    penup()
    setheading(90)
    forward(25)
    setheading(0)
    forward(10)
    pendown()
    # 设置画笔的颜色(红, 绿, 蓝)
    pencolor(255, 155, 192)
    setheading(10)
    begin_fill()
    circle(5)
    color(160, 82, 45)
    end_fill()
    penup()
    setheading(0)
    forward(20)
    pendown()
    pencolor(255, 155, 192)
    setheading(10)
    begin_fill()
    circle(5)
    color(160, 82, 45)
    end_fill()


def head(x, y):
    """画头"""
    color((255, 155, 192), "pink")
    penup()
    goto(x,y)
    setheading(0)
    pendown()
    begin_fill()
    setheading(180)
    circle(300, -30)
    circle(100, -60)
    circle(80, -100)
    circle(150, -20)
    circle(60, -95)
    setheading(161)
    circle(-300, 15)
    penup()
    goto(-100, 100)
    pendown()
    setheading(-30)
    a = 0.4
    for i in range(60):
        if 0<= i < 30 or 60 <= i < 90:
            a = a + 0.08
            lt(3) #向左转3度
            fd(a) #向前走a的步长
        else:
            a = a - 0.08
            lt(3)
            fd(a)
    end_fill()


def ears(x,y):
    """画耳朵"""
    color((255, 155, 192), "pink")
    penup()
    goto(x, y)
    pendown()
    begin_fill()
    setheading(100)
    circle(-50, 50)
    circle(-10, 120)
    circle(-50, 54)
    end_fill()
    penup()
    setheading(90)
    forward(-12)
    setheading(0)
    forward(30)
    pendown()
    begin_fill()
    setheading(100)
    circle(-50, 50)
    circle(-10, 120)
    circle(-50, 56)
    end_fill()


def eyes(x,y):
    """画眼睛"""
    color((255, 155, 192), "white")
    penup()
    setheading(90)
    forward(-20)
    setheading(0)
    forward(-95)
    pendown()
    begin_fill()
    circle(15)
    end_fill()
    color("black")
    penup()
    setheading(90)
    forward(12)
    setheading(0)
    forward(-3)
    pendown()
    begin_fill()
    circle(3)
    end_fill()
    color((255, 155, 192), "white")
    penup()
    seth(90)
    forward(-25)
    seth(0)
    forward(40)
    pendown()
    begin_fill()
    circle(15)
    end_fill()
    color("black")
    penup()
    setheading(90)
    forward(12)
    setheading(0)
    forward(-3)
    pendown()
    begin_fill()
    circle(3)
    end_fill()


def cheek(x,y):
    """画脸颊"""
    color((255, 155, 192))
    penup()
    goto(x,y)
    pendown()
    setheading(0)
    begin_fill()
    circle(30)
    end_fill()


def mouth(x,y):
    """画嘴巴"""
    color(239, 69, 19)
    penup()
    goto(x, y)
    pendown()
    setheading(-80)
    circle(30, 40)
    circle(40, 80)


def setting():
    """设置参数"""
    pensize(4)
    # 隐藏海龟
    hideturtle()
    colormode(255)
    color((255, 155, 192), "pink")
    setup(840, 500)
    speed(3000)



"""主函数"""
setting()
nose(-100, 100)
head(-69, 167)
ears(0, 160)
# eyes(0, 140)
cheek(80, 10)
mouth(-20, 30)
"""画猪点睛。
   从这里开始填写你的代码
   你需要给小猪佩奇加上两个囧囧有神的黑眼睛。
   提示：佩奇的左眼的中心坐标是（0，140），这只是一个建议值，如果你能找到更好的
           眼睛的坐标请按照你的想法来发挥
"""
import turtle as t
t.penup()
t.goto(0, 130)
t.pendown()
t.color('white', "pink")
t.dot(20)
t.color('black', 'black')
t.dot(5)

t.penup()
t.goto(20,110)
t.pendown()
t.color('white', "pink")
t.dot(20)
t.color('black', 'black')
t.dot(5)

"""这里结束了哦"""
done()

# %%
import turtle as t
t.speed(1)
t.screensize(800,600, 'white')
t.circle(30)
t.penup()
t.forward(150)
t.pendown()
t.circle(30)
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in circle(radius, extent, steps)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in circle(self, radius, extent, steps)
#    1990             self.speed(speed)
# -> 1991             self._go(l)
#    1992             self.speed(0)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in _go(self, distance)
#    1604         ende = self._position + self._orient * distance
# -> 1605         self._goto(ende)
#    1606
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in _goto(self, end)
#    3177                                      (start, self._position),
# -> 3178                                      self._pencolor, self._pensize, top)
#    3179                 self._update()
#
# ...

# %%
import turtle as t 
t.speed(1)
# t.screensize(400,400,'white')
screen = t.Screen()
screen.bgpic("test.png")
# t.bgpic('test.gif')
t.dot(100)
t.penup()
t.forward(100)
t.pendown()
t.dot(100)
t.onscreenclick(t.dot(10))
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-80fdd57625cf> in <module>()
#       3 # t.screensize(400,400,'white')
#       4 screen = t.Screen()
# ----> 5 screen.bgpic("test.png")
#       6 # t.bgpic('test.gif')
#       7 t.dot(100)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in bgpic(self, picname)
#    1479             return self._bgpicname
#    1480         if picname not in self._bgpics:
# -> 1481             self._bgpics[picname] = self._image(picname)
#    1482         self._setbgpic(self._bgpic, self._bgpics[picname])
#    1483         self._bgpicname = picname
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in _image(filename)
#     477         imagedata from a gif-file named filename.
#     478         """
# --> 479         return TK.PhotoImage(file=filename)
#     480
# ...

# %%
import turtle as t
t.screensize(20,20,'blue')
t.speed(1)
t.forward(50)
t.left(90)
t.pensize(4)
t.color("pink", "white")
t.begin_fill()
t.circle(30)
t.end_fill()
t.left(90)
t.penup()
t.forward(20)
t.color('black')
t.pendown()
t.dot(20)
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-8-9658a741feac> in <module>()
#      16 t.dot(20)
#      17 t.done()
# ---> 18 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
import turtle as t
t.speed(1)
t.screensize(200,200,'white')
t.pensize(4)

t.color("blue", "red")
t.begin_fill()
t.circle(30)
t.end_fill()
t.penup()
t.forward(100)
t.pendown()

t.color('blue','black')
t.begin_fill()
t.circle(30)
t.end_fill()
t.forward(50)
t.dot(40)
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-16-163c52bc0691> in <module>()
#      19 t.dot(40)
#      20 t.done()
# ---> 21 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
import turtle as t
t.speed(1)
# t.screensize(200,200,'white')
screen = t.Screen()

screen.bgpic("/Users/fengyichen/pldev/newfolder/PrairieLearn/s.gif")
t.pensize(4)
# t.bgpic(r's.gif')
t.color("blue", "black")
t.begin_fill()
t.circle(30)
t.end_fill()

t.left(90)
t.penup()
t.forward(30)
t.pendown()
t.color('white', 'black')
t.dot(10)
t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-b1925680d74b> in <module>()
#       4 screen = t.Screen()
#       5
# ----> 6 screen.bgpic("/Users/fengyichen/pldev/newfolder/PrairieLearn/s.gif")
#       7 t.pensize(4)
#       8 # t.bgpic(r's.gif')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in bgpic(self, picname)
#    1479             return self._bgpicname
#    1480         if picname not in self._bgpics:
# -> 1481             self._bgpics[picname] = self._image(picname)
#    1482         self._setbgpic(self._bgpic, self._bgpics[picname])
#    1483         self._bgpicname = picname
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in _image(filename)
#     477         imagedata from a gif-file named filename.
#     478         """
# --> 479         return TK.PhotoImage(file=filename)
#     480
# ...

# %%
import turtle as t
t.screensize(200, 200, 'white')
t.speed(1)

t.circle(30)
t.penup()
t.forward(100)
t.pendown()
t.circle(30)

t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-3-a979113e2d3a> in <module>()
#      10
#      11 t.done()
# ---> 12 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
import turtle as t
t.speed(1)
t.screensize(200,200, 'white')
t.pensize(4)

t.color('blue', 'black')
t.begin_fill()
t.circle(40)
t.end_fill()

t.left(90)
t.penup()
t.forward(40)
t.pendown()

t.color('white', 'black')
t.dot(15)
# t.penup()
# t.forward(100)
# t.pendown()

# t.color('blue', 'black')
# t.begin_fill()
# t.circle(40)
# t.end_fill()

t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-14-e727c3c65ea5> in <module>()
#      26
#      27 t.done()
# ---> 28 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
import turtle as t
t.speed(1)
t.pensize(4)

t.screensize(200,200, 'white')

# t.color('blue', 'red')
# t.begin_fill()
# t.circle(30)
# t.end_fill()

# t.penup()
# t.forward(100)
# t.pendown()

t.color('blue', 'black')
t.begin_fill()
t.circle(30)
t.end_fill()

t.left(90)
t.penup()
t.forward(30)
t.pendown()
t.color('white', 'black')
t.dot(15)

t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-22-62b09b8f4861> in <module>()
#      27
#      28 t.done()
# ---> 29 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:

# %%
import turtle as t
t.speed(1)
t.screensize(200,200,'white')
t.pensize(4)

# t.color('blue', 'red')
# t.begin_fill()
# t.circle(30)
# t.end_fill()
t.penup()
t.color('blue', 'black')
# t.forward(100)
t.pendown()
t.begin_fill()
t.circle(30)
t.end_fill()

t.left(90)
t.penup()
t.forward(30)
t.pendown()
t.color('white', 'black')
t.dot(15)

t.done()
t.clear()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-32-e78c1eb4dd3d> in <module>()
#      24
#      25 t.done()
# ---> 26 t.clear()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/turtle.py in clear()
#
# Terminator:
